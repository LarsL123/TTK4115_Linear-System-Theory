# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

# -----------------------------------------------------------
# FILES
# -----------------------------------------------------------
FILE_EST = 'X_kestimatesQ_6times1.mat'
FILE_ENC = 'encoder_values_Q_6times1.mat'
FILE_COV = 'P_kestimates_Q_6times1.mat'

# -----------------------------------------------------------
# MANUAL SIGNAL MAPPING
# Left  = estimate signal index
# Right = encoder signal index
#
# Only fill in the pairs you know match.
# Any signal not in this mapping will still be plotted alone.
# -----------------------------------------------------------
MAPPING = {
    1: 3,   # Pitch
    2: 4,   # Pitch Rate
    3: 5,   # Elevation
    4: 6,   # Elevation Rate
    5: 1,   # Travel 
    6: 2,   # Travel Rate

}

# Optional display names (fallback: “Signal i”)
LABELS = {
    1: "Pitch",
    2: "Pitch Rate",
    3: "Elevation",
    4: "Elevation Rate",
    5: "Travel",
    6: "Travel Rate",
}

COVARIANCE_LABELS = {
    1: "Pitch",
    2: "Pitch Rate",
    3: "Elevation",
    4: "Elevation Rate",
    5: "Travel",
    6: "Travel Rate",
}

# -----------------------------------------------------------
# TIME WINDOW
# -----------------------------------------------------------
t_min = 0
t_max = 15

# -----------------------------------------------------------
# LOAD FILES
# -----------------------------------------------------------
def load_data(path):
    data = scipy.io.loadmat(path)
    print("\nVariables in the .mat file:")
    for key in data.keys():
        if not key.startswith("__"):
            val = data[key]
            print(f"- {key}: shape {val.shape if hasattr(val, 'shape') else type(val)}")
    return data["ans"]

est = load_data(FILE_EST)
enc = load_data(FILE_ENC)
cov = load_data(FILE_COV)

# -----------------------------------------------------------
# TIME CROPPING
# -----------------------------------------------------------
time_est = est[0, :]
time_enc = enc[0, :]

mask_est = (time_est >= t_min) & (time_est <= t_max)
mask_enc = (time_enc >= t_min) & (time_enc <= t_max)
mask_cov = (time_est >= t_min) & (time_est <= t_max)

# -----------------------------------------------------------
# Determine which signals exist
# -----------------------------------------------------------
est_signals = set(range(1, est.shape[0]))   # skip index 0 (time)
enc_signals = set(range(1, enc.shape[0]))

mapped_est   = set(MAPPING.keys())
mapped_enc   = {v for v in MAPPING.values() if v is not None}

unmatched_est = est_signals - mapped_est
unmatched_enc = enc_signals - mapped_enc

# -----------------------------------------------------------
# Total number of subplots = matched + unmatched
# -----------------------------------------------------------
total_plots = len([i for i in MAPPING if MAPPING[i] is not None]) \
              + len(unmatched_est) + len(unmatched_enc)

total_plots += 1 # Add one extra plot for covariance

cols = 2
rows = int(np.ceil(total_plots / cols))

fig, axes = plt.subplots(rows, cols, figsize=(12, rows * 3))
axes = axes.flatten()

plot_i = 0

# -----------------------------------------------------------
# 1) Plot matched pairs
# -----------------------------------------------------------
for est_idx, enc_idx in MAPPING.items():
    if enc_idx is None:
        continue

    ax = axes[plot_i]

    est_signal = est[est_idx, mask_est]
    enc_signal = enc[enc_idx, mask_enc]

    ax.plot(time_est[mask_est], est_signal, label="Estimate")
    ax.plot(time_enc[mask_enc], enc_signal, label="Encoder")

    title = LABELS.get(est_idx, f"Signal {est_idx}")
    ax.set_title(title + f" (Est {est_idx} ↔ Enc {enc_idx})")

    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Amplitude")
    ax.grid(True)
    ax.legend()

    plot_i += 1


# -----------------------------------------------------------
# 2) Plot 
# -----------------------------------------------------------
# for est_idx in unmatched_est:
#     ax = axes[plot_i]

#     est_signal = est[est_idx, mask_est]
#     ax.plot(time_est[mask_est], est_signal, label="Estimate")

#     title = LABELS.get(est_idx, f"Signal {est_idx}")
#     ax.set_title(title + f" (Est {est_idx} only)")

#     ax.set_xlabel("Time [s]")
#     ax.set_ylabel("Amplitude")
#     ax.grid(True)
#     ax.legend()
#     plot_i += 1

# -----------------------------------------------------------
# 3) Plot Covariance
# -----------------------------------------------------------
ax = axes[plot_i]
for index, name in COVARIANCE_LABELS.items():
    

    covar_signal = cov[index, mask_cov]
    ax.plot(time_est[mask_cov], covar_signal, label=("Covariance "+name))
    
    ax.set_title("Covariance Signals")

    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Amplitude")
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Variables in the .mat file:
# - ans: shape (7, 7950)
#
# Variables in the .mat file:
# - ans: shape (7, 7950)
#
# Variables in the .mat file:
# - ans: shape (7, 7950)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

# -----------------------------------------------------------
# FILES
# -----------------------------------------------------------
FILE_EST = 'X_kestimatesQ_6times0.005.mat'
FILE_ENC = 'encoder_values_Q_6times0.005.mat'
FILE_COV = 'P_kestimates_Q_6times0.005.mat'

# -----------------------------------------------------------
# MANUAL SIGNAL MAPPING
# Left  = estimate signal index
# Right = encoder signal index
#
# Only fill in the pairs you know match.
# Any signal not in this mapping will still be plotted alone.
# -----------------------------------------------------------
MAPPING = {
    1: 3,   # Pitch
    2: 4,   # Pitch Rate
    3: 5,   # Elevation
    4: 6,   # Elevation Rate
    5: 1,   # Travel 
    6: 2,   # Travel Rate

}

# Optional display names (fallback: “Signal i”)
LABELS = {
    1: "Pitch",
    2: "Pitch Rate",
    3: "Elevation",
    4: "Elevation Rate",
    5: "Travel",
    6: "Travel Rate",
}

COVARIANCE_LABELS = {
    1: "Pitch",
    2: "Pitch Rate",
    3: "Elevation",
    4: "Elevation Rate",
    5: "Travel",
    6: "Travel Rate",
}

# -----------------------------------------------------------
# TIME WINDOW
# -----------------------------------------------------------
t_min = 0
t_max = 15

# -----------------------------------------------------------
# LOAD FILES
# -----------------------------------------------------------
def load_data(path):
    data = scipy.io.loadmat(path)
    print("\nVariables in the .mat file:")
    for key in data.keys():
        if not key.startswith("__"):
            val = data[key]
            print(f"- {key}: shape {val.shape if hasattr(val, 'shape') else type(val)}")
    return data["ans"]

est = load_data(FILE_EST)
enc = load_data(FILE_ENC)
cov = load_data(FILE_COV)

# -----------------------------------------------------------
# TIME CROPPING
# -----------------------------------------------------------
time_est = est[0, :]
time_enc = enc[0, :]

mask_est = (time_est >= t_min) & (time_est <= t_max)
mask_enc = (time_enc >= t_min) & (time_enc <= t_max)
mask_cov = (time_est >= t_min) & (time_est <= t_max)

# -----------------------------------------------------------
# Determine which signals exist
# -----------------------------------------------------------
est_signals = set(range(1, est.shape[0]))   # skip index 0 (time)
enc_signals = set(range(1, enc.shape[0]))

mapped_est   = set(MAPPING.keys())
mapped_enc   = {v for v in MAPPING.values() if v is not None}

unmatched_est = est_signals - mapped_est
unmatched_enc = enc_signals - mapped_enc

# -----------------------------------------------------------
# Total number of subplots = matched + unmatched
# -----------------------------------------------------------
total_plots = len([i for i in MAPPING if MAPPING[i] is not None]) \
              + len(unmatched_est) + len(unmatched_enc)

total_plots += 1 # Add one extra plot for covariance

cols = 2
rows = int(np.ceil(total_plots / cols))

fig, axes = plt.subplots(rows, cols, figsize=(12, rows * 3))
axes = axes.flatten()

plot_i = 0

# -----------------------------------------------------------
# 1) Plot matched pairs
# -----------------------------------------------------------
for est_idx, enc_idx in MAPPING.items():
    if enc_idx is None:
        continue

    ax = axes[plot_i]

    est_signal = est[est_idx, mask_est]
    enc_signal = enc[enc_idx, mask_enc]

    ax.plot(time_est[mask_est], est_signal, label="Estimate")
    ax.plot(time_enc[mask_enc], enc_signal, label="Encoder")

    title = LABELS.get(est_idx, f"Signal {est_idx}")
    ax.set_title(title + f" (Est {est_idx} ↔ Enc {enc_idx})")

    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Amplitude")
    ax.grid(True)
    ax.legend()

    plot_i += 1


# -----------------------------------------------------------
# 2) Plot 
# -----------------------------------------------------------
# for est_idx in unmatched_est:
#     ax = axes[plot_i]

#     est_signal = est[est_idx, mask_est]
#     ax.plot(time_est[mask_est], est_signal, label="Estimate")

#     title = LABELS.get(est_idx, f"Signal {est_idx}")
#     ax.set_title(title + f" (Est {est_idx} only)")

#     ax.set_xlabel("Time [s]")
#     ax.set_ylabel("Amplitude")
#     ax.grid(True)
#     ax.legend()
#     plot_i += 1

# -----------------------------------------------------------
# 3) Plot Covariance
# -----------------------------------------------------------
ax = axes[plot_i]
for index, name in COVARIANCE_LABELS.items():
    

    covar_signal = cov[index, mask_cov]
    ax.plot(time_est[mask_cov], covar_signal, label=("Covariance "+name))
    
    ax.set_title("Covariance Signals")

    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Amplitude")
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Variables in the .mat file:
# - ans: shape (7, 9358)
#
# Variables in the .mat file:
# - ans: shape (7, 9358)
#
# Variables in the .mat file:
# - ans: shape (7, 9358)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

# -----------------------------------------------------------
# FILES
# -----------------------------------------------------------
FILE_EST = 'X_kestimatesQ_6times100000.mat'
FILE_ENC = 'encoder_values_Q_6times100000.mat'
FILE_COV = 'P_kestimates_Q_6times100000.mat'

# -----------------------------------------------------------
# MANUAL SIGNAL MAPPING
# Left  = estimate signal index
# Right = encoder signal index
#
# Only fill in the pairs you know match.
# Any signal not in this mapping will still be plotted alone.
# -----------------------------------------------------------
MAPPING = {
    1: 3,   # Pitch
    2: 4,   # Pitch Rate
    3: 5,   # Elevation
    4: 6,   # Elevation Rate
    5: 1,   # Travel 
    6: 2,   # Travel Rate

}

# Optional display names (fallback: “Signal i”)
LABELS = {
    1: "Pitch",
    2: "Pitch Rate",
    3: "Elevation",
    4: "Elevation Rate",
    5: "Travel",
    6: "Travel Rate",
}

COVARIANCE_LABELS = {
    1: "Pitch",
    2: "Pitch Rate",
    3: "Elevation",
    4: "Elevation Rate",
    5: "Travel",
    6: "Travel Rate",
}

# -----------------------------------------------------------
# TIME WINDOW
# -----------------------------------------------------------
t_min = 0
t_max = 15

# -----------------------------------------------------------
# LOAD FILES
# -----------------------------------------------------------
def load_data(path):
    data = scipy.io.loadmat(path)
    print("\nVariables in the .mat file:")
    for key in data.keys():
        if not key.startswith("__"):
            val = data[key]
            print(f"- {key}: shape {val.shape if hasattr(val, 'shape') else type(val)}")
    return data["ans"]

est = load_data(FILE_EST)
enc = load_data(FILE_ENC)
cov = load_data(FILE_COV)

# -----------------------------------------------------------
# TIME CROPPING
# -----------------------------------------------------------
time_est = est[0, :]
time_enc = enc[0, :]

mask_est = (time_est >= t_min) & (time_est <= t_max)
mask_enc = (time_enc >= t_min) & (time_enc <= t_max)
mask_cov = (time_est >= t_min) & (time_est <= t_max)

# -----------------------------------------------------------
# Determine which signals exist
# -----------------------------------------------------------
est_signals = set(range(1, est.shape[0]))   # skip index 0 (time)
enc_signals = set(range(1, enc.shape[0]))

mapped_est   = set(MAPPING.keys())
mapped_enc   = {v for v in MAPPING.values() if v is not None}

unmatched_est = est_signals - mapped_est
unmatched_enc = enc_signals - mapped_enc

# -----------------------------------------------------------
# Total number of subplots = matched + unmatched
# -----------------------------------------------------------
total_plots = len([i for i in MAPPING if MAPPING[i] is not None]) \
              + len(unmatched_est) + len(unmatched_enc)

total_plots += 1 # Add one extra plot for covariance

cols = 2
rows = int(np.ceil(total_plots / cols))

fig, axes = plt.subplots(rows, cols, figsize=(12, rows * 3))
axes = axes.flatten()

plot_i = 0

# -----------------------------------------------------------
# 1) Plot matched pairs
# -----------------------------------------------------------
for est_idx, enc_idx in MAPPING.items():
    if enc_idx is None:
        continue

    ax = axes[plot_i]

    est_signal = est[est_idx, mask_est]
    enc_signal = enc[enc_idx, mask_enc]

    ax.plot(time_est[mask_est], est_signal, label="Estimate")
    ax.plot(time_enc[mask_enc], enc_signal, label="Encoder")

    title = LABELS.get(est_idx, f"Signal {est_idx}")
    ax.set_title(title + f" (Est {est_idx} ↔ Enc {enc_idx})")

    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Amplitude")
    ax.grid(True)
    ax.legend()

    plot_i += 1


# -----------------------------------------------------------
# 2) Plot 
# -----------------------------------------------------------
# for est_idx in unmatched_est:
#     ax = axes[plot_i]

#     est_signal = est[est_idx, mask_est]
#     ax.plot(time_est[mask_est], est_signal, label="Estimate")

#     title = LABELS.get(est_idx, f"Signal {est_idx}")
#     ax.set_title(title + f" (Est {est_idx} only)")

#     ax.set_xlabel("Time [s]")
#     ax.set_ylabel("Amplitude")
#     ax.grid(True)
#     ax.legend()
#     plot_i += 1

# -----------------------------------------------------------
# 3) Plot Covariance
# -----------------------------------------------------------
ax = axes[plot_i]
for index, name in COVARIANCE_LABELS.items():
    

    covar_signal = cov[index, mask_cov]
    ax.plot(time_est[mask_cov], covar_signal, label=("Covariance "+name))
    
    ax.set_title("Covariance Signals")

    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Amplitude")
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Variables in the .mat file:
# - ans: shape (7, 5930)
#
# Variables in the .mat file:
# - ans: shape (7, 5930)
#
# Variables in the .mat file:
# - ans: shape (7, 5930)

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

# -----------------------------------------------------------
# FILES
# -----------------------------------------------------------
FILE_EST = 'X_kestimatesQ_6timesgoestozero.mat'
FILE_ENC = 'encoder_values_Q_6timesgoestozero.mat'
FILE_COV = 'P_kestimates_Q_6timesgoestozero.mat'

# -----------------------------------------------------------
# MANUAL SIGNAL MAPPING
# Left  = estimate signal index
# Right = encoder signal index
#
# Only fill in the pairs you know match.
# Any signal not in this mapping will still be plotted alone.
# -----------------------------------------------------------
MAPPING = {
    1: 3,   # Pitch
    2: 4,   # Pitch Rate
    3: 5,   # Elevation
    4: 6,   # Elevation Rate
    5: 1,   # Travel 
    6: 2,   # Travel Rate

}

# Optional display names (fallback: “Signal i”)
LABELS = {
    1: "Pitch",
    2: "Pitch Rate",
    3: "Elevation",
    4: "Elevation Rate",
    5: "Travel",
    6: "Travel Rate",
}

COVARIANCE_LABELS = {
    1: "Pitch",
    2: "Pitch Rate",
    3: "Elevation",
    4: "Elevation Rate",
    5: "Travel",
    6: "Travel Rate",
}

# -----------------------------------------------------------
# TIME WINDOW
# -----------------------------------------------------------
t_min = 0
t_max = 15

# -----------------------------------------------------------
# LOAD FILES
# -----------------------------------------------------------
def load_data(path):
    data = scipy.io.loadmat(path)
    print("\nVariables in the .mat file:")
    for key in data.keys():
        if not key.startswith("__"):
            val = data[key]
            print(f"- {key}: shape {val.shape if hasattr(val, 'shape') else type(val)}")
    return data["ans"]

est = load_data(FILE_EST)
enc = load_data(FILE_ENC)
cov = load_data(FILE_COV)

# -----------------------------------------------------------
# TIME CROPPING
# -----------------------------------------------------------
time_est = est[0, :]
time_enc = enc[0, :]

mask_est = (time_est >= t_min) & (time_est <= t_max)
mask_enc = (time_enc >= t_min) & (time_enc <= t_max)
mask_cov = (time_est >= t_min) & (time_est <= t_max)

# -----------------------------------------------------------
# Determine which signals exist
# -----------------------------------------------------------
est_signals = set(range(1, est.shape[0]))   # skip index 0 (time)
enc_signals = set(range(1, enc.shape[0]))

mapped_est   = set(MAPPING.keys())
mapped_enc   = {v for v in MAPPING.values() if v is not None}

unmatched_est = est_signals - mapped_est
unmatched_enc = enc_signals - mapped_enc

# -----------------------------------------------------------
# Total number of subplots = matched + unmatched
# -----------------------------------------------------------
total_plots = len([i for i in MAPPING if MAPPING[i] is not None]) \
              + len(unmatched_est) + len(unmatched_enc)

total_plots += 1 # Add one extra plot for covariance

cols = 2
rows = int(np.ceil(total_plots / cols))

fig, axes = plt.subplots(rows, cols, figsize=(12, rows * 3))
axes = axes.flatten()

plot_i = 0

# -----------------------------------------------------------
# 1) Plot matched pairs
# -----------------------------------------------------------
for est_idx, enc_idx in MAPPING.items():
    if enc_idx is None:
        continue

    ax = axes[plot_i]

    est_signal = est[est_idx, mask_est]
    enc_signal = enc[enc_idx, mask_enc]

    ax.plot(time_est[mask_est], est_signal, label="Estimate")
    ax.plot(time_enc[mask_enc], enc_signal, label="Encoder")

    title = LABELS.get(est_idx, f"Signal {est_idx}")
    ax.set_title(title + f" (Est {est_idx} ↔ Enc {enc_idx})")

    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Amplitude")
    ax.grid(True)
    ax.legend()

    plot_i += 1


# -----------------------------------------------------------
# 2) Plot 
# -----------------------------------------------------------
# for est_idx in unmatched_est:
#     ax = axes[plot_i]

#     est_signal = est[est_idx, mask_est]
#     ax.plot(time_est[mask_est], est_signal, label="Estimate")

#     title = LABELS.get(est_idx, f"Signal {est_idx}")
#     ax.set_title(title + f" (Est {est_idx} only)")

#     ax.set_xlabel("Time [s]")
#     ax.set_ylabel("Amplitude")
#     ax.grid(True)
#     ax.legend()
#     plot_i += 1

# -----------------------------------------------------------
# 3) Plot Covariance
# -----------------------------------------------------------
ax = axes[plot_i]
for index, name in COVARIANCE_LABELS.items():
    

    covar_signal = cov[index, mask_cov]
    ax.plot(time_est[mask_cov], covar_signal, label=("Covariance "+name))
    
    ax.set_title("Covariance Signals")

    ax.set_xlabel("Time [s]")
    ax.set_ylabel("Amplitude")
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Variables in the .mat file:
# - ans: shape (7, 4906)
#
# Variables in the .mat file:
# - ans: shape (7, 4906)
#
# Variables in the .mat file:
# - ans: shape (7, 4906)
